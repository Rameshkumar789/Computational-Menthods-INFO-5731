# %% [markdown]
# <a href="https://colab.research.google.com/github/Rameshkumar789/Computational-Menthods-INFO-5731/blob/main/Korlakunta_Assignment_Two.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **INFO5731 Assignment Two**
#
# In this assignment, you will try to gather text data from open data source via web scraping or API. After that you need to clean the text data and syntactic analysis of the data.

# %% [markdown]
# # **Question 1**

# %% [markdown]
# (40 points). Write a python program to collect text data from **either of the following sources** and save the data into a **csv file**:
#
# (1) Collect all the customer reviews of the product [2019 Dell labtop](https://www.amazon.com/Dell-Inspiron-5000-5570-Laptop/dp/B07N49F51N/ref=sr_1_11?crid=1IJ7UWF2F4GHH&keywords=dell%2Bxps%2B15&qid=1580173569&sprefix=dell%2Caps%2C181&sr=8-11&th=1) on amazon.
#
# (2) Collect the top 100 User Reviews of the film [Joker](https://www.imdb.com/title/tt7286456/reviews?ref_=tt_urv) from IMDB.
#
# (3) Collect the abstracts of the top 100 research papers by using the query [natural language processing](https://citeseerx.ist.psu.edu/search?q=natural+language+processing&submit.x=0&submit.y=0&sort=rlv&t=doc) from CiteSeerX.
#
# (4) Collect the top 100 tweets by using hashtag ["#CovidVaccine"](https://twitter.com/hashtag/CovidVaccine) from Twitter.

# %%
import tweepy as tw
import pandas as pd

# %%
def scrape_twitter(consumer_keys, consumer_secret, access_token, access_token_secret):
    auth = tw.OAuthHandler(consumer_keys, consumer_secret)
    auth.set_access_token(access_token, access_token_secret)
    api = tw.API(auth)
    
    query = '#CovidVaccine'
    count = 100
    
    tweets = tw.Cursor(api.search,q=query+ " -filter:retweets", lang="en").items(count)
    temp=[]
    for i in tweets:
        temp.append(i.text)
    
    data=pd.DataFrame({'Original':temp})
    return data

# %%
consumer_keys=input("Enter the consumer key")
consumer_secret=input("Enter the consumer_secret")
access_token=input("Enter the access_token")
access_token_secret=input("Enter the access_token_secret")

# %%
data = scrape_twitter(consumer_keys, consumer_secret, access_token, access_token_secret)

# %%
data.to_csv("Tweets_data.csv")

# %% [markdown]
# # **Question 2**

# %% [markdown]
# (30 points). Write a python program to **clean the text data** you collected above and save the data in a new column in the csv file. The data cleaning steps include:
#
# (1) Remove noise, such as special characters and punctuations.
#
# (2) Remove numbers.
#
# (3) Remove stopwords by using the [stopwords list](https://gist.github.com/sebleier/554280).
#
# (4) Lowercase all texts
#
# (5) Stemming.
#
# (6) Lemmatization.

# %%
# Write your code here
import nltk
from nltk.corpus import stopwords
nltk.download('stopwords')
stop=stopwords.words('english')
from textblob import TextBlob
from nltk.stem import PorterStemmer
from textblob import Word
import numpy as np
import pandas as pd
nltk.download('punkt')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
data['Modified']=data['Original']

# %%
#Noise
data['Modified']=data['Modified'].str.replace(r'[^\w\s]+', '')

#Numbers
data['Modified']= data['Modified'].apply(lambda x: " ".join(x for x in x.split() if not x.isdigit()))

#Stopwords removal
data['Modified']=data['Modified'].apply(lambda x: " ".join(x for x in x.split() if x not in stop))

#Lower casing
data['Modified']=data['Modified'].apply(lambda x: " ".join(x.lower() for x in x.split()))

#Stemming
temp=PorterStemmer()
data['Modified']=data['Modified'].apply(lambda x: " ".join([temp.stem(word) for word in x.split()]))

#Lemmatization
data['Modified']=data['Modified'].apply(lambda x: " ".join([Word(word).lemmatize() for word in x.split()]))
data
# Out:
#                                              Original                                           Modified
# 0   Got my #COVIDVaccine today! First dose! One mo...  got covidvaccin today first dose one go ill fu...
# 1   I was eligible for the Covid19 vaccine 2/8, bu...  i elig covid19 vaccin i get first shot my seco...
# 2   How do you know which one is right for you? #C...  how know one right covidvaccin httpstcov2ydw8ggw9
# 3   Thank you @WCSedu nurses and the staff that ma...  thank wcsedu nurs staff made vaccin distribut ...
# 4   @mentionitaII Me, regarding the two doses of t...  mentionitaii me regard two dose pfizer vaccin ...
# ..                                                ...                                                ...
# 95  How dare you not advise us on the experimental...  how dare advis u experiment natur covidvaccin ...
# 96  #Pfizer #CovidVaccine Reduces Transmission Aft...  pfizer covidvaccin reduc transmiss after one d...
# ...

# %%
data.to_csv("Tweets_data.csv")

# %% [markdown]
# # **Question 3**

# %% [markdown]
# (30 points). Write a python program to conduct **syntax and structure analysis** of the clean text you just saved above. The syntax and structure analysis includes:
#
# (1) Parts of Speech (POS) Tagging: Tag Parts of Speech of each word in the text, and calculate the total number of N(oun), V(erb), Adj(ective), Adv(erb), respectively.
#
# (2) Constituency Parsing and Dependency Parsing: print out the constituency parsing trees and dependency parsing trees of all the sentences. Using one sentence as an example to explain your understanding about the constituency parsing tree and dependency parsing tree.
#
# (3) Named Entity Recognition: Extract all the entities such as person names, organizations, locations, product names, and date from the clean texts, calculate the count of each entity.

# %% [markdown]
# ## Parts of Speech (POS) Tagging

# %%
from nltk import word_tokenize, pos_tag
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# True

# %%
n=0
v=0
adj=0
adv=0

for i in range(len(data)):
    words = word_tokenize(data['Modified'][i])
    tag = pos_tag(words)
    #print(tag)
    for j in range(len(tag)):
        if (tag[j][1]=='NN' or tag[j][1]=='NNS' or tag[j][1]=='NNP'or tag[j][1]=='NNPS'):
            n=n+1
        elif (tag[j][1]=='VB'or tag[j][1]=='VBG' or tag[j][1]=='VBD'or tag[j][1]=='VBN'or tag[j][1]=='VBP'or tag[j][1]=='VBZ'):
            v=v+1
        elif (tag[j][1]=='JJ'or tag[j][1]=='JJR' or tag[j][1]=='JJS'):
            adj=adj+1
        elif (tag[j][1]=='RB'or tag[j][1]=='RBR' or tag[j][1]=='RBS'):
            adv=adv+1
        
print("No of Nouns:"+str(n))
print("No of Verbs:"+str(v))
print("No of Adjectives:"+str(adj))
print("No of Adverbs:"+str(adv))
# Out:
# No of Nouns:685
# No of Verbs:151
# No of Adjectives:163
# No of Adverbs:34

# %% [markdown]
# ## Constituency Parsing and Dependency Parsing

# %% [markdown]
# ### Dependency Parsing

# %%
import spacy
from spacy import displacy

samp=spacy.load('en_core_web_sm')

# %%
for i in range(len(data)):
    print("Sentence: " +str(i+1))
    for j in samp(data['Modified'][i]):
        print(j.text,'=>',j.dep_,'=>',j.head.text)
    spacy.displacy.render(samp(data['Modified'][i]),jupyter=True)
# Out:
# Sentence: 1
# got => advcl => dose
# covidvaccin => dobj => got
# today => npadvmod => got
# first => advmod => dose
# dose => ROOT => dose
# one => nsubj => go
# go => ccomp => dose
# ill => amod => turningintoasuperhero
# full => amod => turningintoasuperhero
# power => compound => turningintoasuperhero
# turningintoasuperhero => npadvmod => go
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="0e103319fd864c9a9e1979745b71f989-0" class="displacy" width="1975" height="487.0" direction="ltr" style="max-width: none; height: 487.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">got</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">VERB</tspan>
# </text>
#
# ...

# %% [markdown]
# ### Constituency Parsing

# %%
import benepar
benepar.download('benepar_en3')
from benepar.spacy_plugin import BeneparComponent
# Out:
# [nltk_data] Downloading package benepar_en3 to /root/nltk_data...
# [nltk_data]   Package benepar_en3 is already up-to-date!
# /usr/local/lib/python3.7/dist-packages/benepar/spacy_plugin.py:12: FutureWarning: BeneparComponent and NonConstituentException have been moved to the benepar module. Use `from benepar import BeneparComponent, NonConstituentException` instead of benepar.spacy_plugin. The benepar.spacy_plugin namespace is deprecated and will be removed in a future version.
#   FutureWarning,

# %%
samp = spacy.load('en_core_web_sm')
samp.add_pipe(benepar.BeneparComponent("benepar_en3"))
for i in range(len(data)):
    print("Sentence: " +str(i+1))
    print(list(samp(data['Modified'][i]).sents)[0]._.parse_string)
    print(" ")
# Out:
# Sentence: 1
# (VP (VBD got) (NP (NN covidvaccin)) (NP (NP (NN today)) (NP (JJ first) (NN dose) (CD one))) (VP (VP (VB go) (ADVP (RB ill)) (NP (JJ full) (NN power))) (NN turningintoasuperhero)))
#
# Sentence: 2
# (S (NP (PRP i)) (VP (IN elig) (NP (CD covid19) (FW vaccin))))
#
# Sentence: 3
# (WHADVP (WHADVP (WHADVP (WRB how)) (VBP know)) (NP (NP (PRP one)) (NP (JJ right) (NN covidvaccin) ('' httpstcov2ydw8ggw9))))
#
# Sentence: 4
# (VP (NP (VB thank) (NP (FW wcsedu) (NNP nurs) (NN staff))) (VP (VBD made) (S (NN vaccin) (VP (VB distribut) (NP (FW easi) (NN process)) (ADVP (RB here)) (NP (S (VP (NN step))) (FW httpstco47drymmzsi))))))
#
# Sentence: 5
# (X (FW mentionitaii) (PRP me) (VP (VBP regard) (NP (NP (CD two) (NN dose) (FW pfizer) (FW vaccin)) (FW i) (NN receiv) (NN decemb) (RB januari) (FW httpstcotpjpdd7ot))))
#
# Sentence: 6
# (S (NP (JJ harryandmeghan) (MD ca) (RB nt) (VP (VB cake))) (VB eat) (NP (NP (FW repprtedli) (NN receiv) (FW covidvaccin)) ('' httpstco2zyvgc58r5)))
#
# ...

# %% [markdown]
# ### Named Entity Recognition

# %%
import spacy
from spacy import displacy
from collections import Counter
samp=spacy.load('en_core_web_sm')

# %%
#person names, organizations, locations, product names, and date

p=0
org=0
loc=0
pro=0
da=0

for i in range(len(data)):
    temp = samp(data['Modified'][i])
    for j in temp.ents:
        if( j.label_ == "PERSON"):
            p=p+1
        elif(j.label_ == "ORG"):
            org=org+1
        elif(j.label_ == "LOC" or j.label_ == "GPE"):
            loc=loc+1
        elif(j.label_ == "PRODUCT"):
            pro=pro+1
        elif(j.label_ == "DATE"):
            da=da+1
print('No of Person names: '+str(p))
print('No of Organization: '+str(org))
print('No of Locations: '+str(loc))
print('No of Products: '+str(pro))
print('No of dates: '+str(da))
# Out:
# No of Person names: 49
# No of Organization: 32
# No of Locations: 24
# No of Products: 1
# No of dates: 18

# %% [markdown]
# **Write your explanations of the constituency parsing tree and dependency parsing tree here (Question 3-2):**

# %%
'''
Write your explanations of the constituency parsing tree and dependency parsing tree here
Dependency Parsing depicts the relationship between each word in a sentence. 
Consistency parsing depicts the sentence in the form of a tree where each level indicates the sub-prases. This sub-prases are the POS tags.

Sentence 11:
ex: Johnson and Johnson vaccine on track for US emergency approval

Dependency Parsing:
johnson => compound => johnson
johnson => nsubj => vaccin
vaccin => ROOT => vaccin
track => compound => approv
u => compound => approv
emerg => compound => approv
approv => compound => covidvaccin
johnsonandjohnson => compound => covidvaccin
covidvaccin => compound => coronaviru
coronaviru => dobj => vaccin
httpstcoxl2mtqbtt1 => npadvmod => coronaviru

Consistency Parsing

(NP (NNP johnson) (NN johnson) (FW vaccin) (NN track) (PRP u) (JJ emerg) (VB approv) (NP (NN johnsonandjohnson) (NN covidvaccin) (NN coronaviru) (CD httpstcoxl2mtqbtt1)))

'''
# Out:
# '\nWrite your explanations of the constituency parsing tree and dependency parsing tree here\n\n\n\n'
